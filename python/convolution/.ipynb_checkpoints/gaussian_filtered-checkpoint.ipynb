# %%
from glob import glob
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d

# %%
path = Path('/home/ruairi/Documents/mikex/denoising/')

# %%
from scipy.io import loadmat 

data = loadmat(matfiles[0])
t = data['timevec'].flatten()
eeg = data['EEGdat']
chan = eeg[:, 1]
fs = 500

# %%
filtered = gaussian_filter1d(chan, 2)

# %%
f, a = plt.subplots()

a.plot(t, chan)
a.plot(t, filtered)
f.show()
# Out:
# /home/ruairi/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:457: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
