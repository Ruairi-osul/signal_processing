# %%
from glob import glob
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage.filters import gaussian_filter1d

# %%
path = Path('/home/ruairi/Documents/mikex/denoising/')

# %%
from scipy.io import loadmat 

data = loadmat(matfiles[0])
t = data['timevec'].flatten()
eeg = data['EEGdat']
chan = eeg[:, 1]
fs = 500

# %%
filtered = gaussian_filter1d(chan, 8)

# %%
f, a = plt.subplots()

a.plot(t, chan, label='original')
a.plot(t, filtered, label='gaussian filtered')
f.legend()
plt.show()
